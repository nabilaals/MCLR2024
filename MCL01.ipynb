# %%
import pandas as pd

# %%
dataset = '/content/african-economic-outlook.csv.zip'

# %%
data = pd.read_csv(dataset)

# %%
data
# Out:
#      Country and Regions                           Country and Regions Name  \
# 0                    DZA                                            Algeria
# 1                    DZA                                            Algeria
# 2                    DZA                                            Algeria
# 3                    DZA                                            Algeria
# 4                    DZA                                            Algeria
# ...                  ...                                                ...
# 1727                 SSA                                 Sub-Saharan Africa
# 1728                 SSA                                 Sub-Saharan Africa
# 1729                 NaN                                                NaN
# 1730             Source:                           African Development Bank
# 1731       Download URL:  http://dataportal.opendataforafrica.org/mhuicc...
#
# ...

# %%
data.head()
# Out:
#   Country and Regions Country and Regions Name Country and Regions - RegionId  \
# 0                 DZA                  Algeria                             DZ
# 1                 DZA                  Algeria                             DZ
# 2                 DZA                  Algeria                             DZ
# 3                 DZA                  Algeria                             DZ
# 4                 DZA                  Algeria                             DZ
#
#           Indicators                                    Indicators Name  \
# 0  NY.GDP.MKTP.KD.ZG                         Real GDP growth (annual %)
# 1  NY.GDP.PCAP.KD.ZG         Real per Capita GDP Growth Rate (annual %)
# 2     NY.GDP.MKTP.KD      Gross domestic product, (constant prices US$)
# 3     NY.GDP.MKTP.CD  Gross domestic product, current prices (curren...
# 4     NE.CON.TETC.CD       Final consumption expenditure  (current US$)
#
# ...

# %%
print(data.dtypes)
# Out:
# Country and Regions                object
# Country and Regions Name           object
# Country and Regions - RegionId     object
# Indicators                         object
# Indicators Name                    object
# Scale                              object
# Units                              object
# 1980                              float64
# 1981                              float64
# 1982                              float64
# 1983                              float64
# 1984                              float64
# 1985                              float64
# 1986                              float64
# 1987                              float64
# 1988                              float64
# 1989                              float64
# 1990                              float64
# 1991                              float64
# 1992                              float64
# 1993                              float64
# 1994                              float64
# ...

# %%
datanoid = data.drop(data.columns[4],axis=1)

# %%
datanoid
# Out:
#      Country and Regions                           Country and Regions Name  \
# 0                    DZA                                            Algeria
# 1                    DZA                                            Algeria
# 2                    DZA                                            Algeria
# 3                    DZA                                            Algeria
# 4                    DZA                                            Algeria
# ...                  ...                                                ...
# 1727                 SSA                                 Sub-Saharan Africa
# 1728                 SSA                                 Sub-Saharan Africa
# 1729                 NaN                                                NaN
# 1730             Source:                           African Development Bank
# 1731       Download URL:  http://dataportal.opendataforafrica.org/mhuicc...
#
# ...

# %%
data.describe()
# Out:
#                 1980           1981           1982           1983  \
# count    1391.000000    1562.000000    1563.000000    1565.000000
# mean     5206.961399    4673.101459    4509.660384    4269.458775
# std     25433.338174   24513.764053   24227.432385   22987.550310
# min    -13530.455584  -24831.687809  -32591.088701  -27609.162681
# 25%        13.743778       7.796051       7.759880       7.016619
# 50%        57.340162      37.662311      39.249372      36.573401
# 75%       957.923497     609.219468     591.243915     551.787440
# max    421123.946158  410150.769857  410079.623750  397146.214149
#
#                 1984           1985           1986           1987  \
# count    1565.000000    1565.000000    1565.000000    1567.000000
# mean     4178.829828    4138.623542    4287.405137    4634.993772
# std     22444.928215   22336.079764   23321.361832   25149.999818
# min    -25329.752793  -19745.288630  -28376.688184  -31695.587418
# ...

# %%
data.loc[:,"1982":].corr()
# Out:
#           1982      1983      1984      1985      1986      1987      1988  \
# 1982  1.000000  0.996433  0.991572  0.985636  0.987294  0.988113  0.989410
# 1983  0.996433  1.000000  0.997954  0.993311  0.994839  0.994853  0.995342
# 1984  0.991572  0.997954  1.000000  0.997857  0.997690  0.994960  0.994689
# 1985  0.985636  0.993311  0.997857  1.000000  0.998342  0.993289  0.991898
# 1986  0.987294  0.994839  0.997690  0.998342  1.000000  0.997145  0.996122
# 1987  0.988113  0.994853  0.994960  0.993289  0.997145  1.000000  0.999354
# 1988  0.989410  0.995342  0.994689  0.991898  0.996122  0.999354  1.000000
# 1989  0.986435  0.993117  0.992714  0.990370  0.994297  0.998416  0.999268
# 1990  0.988483  0.993808  0.991845  0.987622  0.991433  0.996948  0.997769
# 1991  0.990790  0.995423  0.992448  0.985504  0.988958  0.993156  0.993801
# 1992  0.988190  0.992616  0.988943  0.980719  0.985031  0.990627  0.991367
# ...

# %%
# @title 1981 vs 1982

from matplotlib import pyplot as plt
data.plot(kind='scatter', x='1981', y='1982', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# DENGAN **API**

# %%
# !pip install kaggle

# %%
import os
from google.colab import files

# Pastikan file kaggle.json sudah diunggah
if not os.path.exists("/root/.kaggle/kaggle.json"):
    uploaded = files.upload()
    for fn in uploaded.keys():
        print('User uploaded file "{name}" with length {length} bytes'.format(
            name=fn, length=len(uploaded[fn])))
    # Pindahkan file kaggle.json ke direktori yang tepat
    # !mkdir -p ~/.kaggle
    # !mv kaggle.json ~/.kaggle/
    # !chmod 600 /root/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-a86ad67b-cac5-458a-bd03-5436b29ad0af" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a86ad67b-cac5-458a-bd03-5436b29ad0af">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !kaggle datasets list -s "porsche stocks"
# Out:
# ...
# ref                                                          title                                           size  lastUpdated          downloadCount  voteCount  usabilityRating
# -----------------------------------------------------------  ---------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# victorsullivan/cars-stock-dataset                            Cars Stock Dataset                             390KB  2021-08-19 16:24:22            386          8  0.7647059
# techsalerator/end-of-day-pricing-data-germany-techsalerator  End-of-Day Pricing Data Germany Techsalerator   34KB  2023-08-23 14:26:04             10          0  0.5294118

# %%
# !kaggle datasets download victorsullivan/cars-stock-dataset
# Out:
# ...
# 100% 390k/390k [00:00<00:00, 574kB/s]
# 100% 390k/390k [00:00<00:00, 574kB/s]

# %%
# !unzip /content/cars-stock-dataset.zip
# Out:
# Archive:  /content/cars-stock-dataset.zip
#   inflating: 600104.SS.csv
#   inflating: AUDVF.csv
#   inflating: BMW.DE.csv
#   inflating: DAI.DE.csv
#   inflating: F.csv
#   inflating: GM.csv
#   inflating: HMC.csv
#   inflating: HYMTF.csv
#   inflating: LEXUS-SM.NS.csv
#   inflating: NSANY.csv
#   inflating: POAHY.csv
#   inflating: RACE.csv
#   inflating: RYCEY.csv
#   inflating: STLA.csv
#   inflating: TM.csv
#   inflating: TSLA.csv
#   inflating: TTM.csv
#   inflating: VLVLY.csv
#   inflating: VWAGY.csv

# %%
pd.read_csv('/content/POAHY.csv')
# Out:
#             Date   Open   High    Low  Close  Adj Close   Volume
# 0     2016-08-19   5.03   5.08   5.03   5.04   4.408112    12400
# 1     2016-08-22   4.98   5.05   4.98   5.04   4.408112     5000
# 2     2016-08-23   5.11   5.12   5.07   5.07   4.434351    12100
# 3     2016-08-24   5.06   5.06   5.06   5.06   4.425604     3300
# 4     2016-08-25   4.97   4.98   4.94   4.94   4.320649     8000
# ...          ...    ...    ...    ...    ...        ...      ...
# 1253  2021-08-12  10.55  10.71  10.50  10.70  10.700000   951200
# 1254  2021-08-13  10.62  10.68  10.58  10.65  10.650000   543100
# 1255  2021-08-16  10.43  10.47  10.37  10.47  10.470000   474900
# 1256  2021-08-17  10.17  10.17  10.02  10.07  10.070000   882100
# 1257  2021-08-18   9.80   9.91   9.78   9.84   9.840000  1009000
#
# [1258 rows x 7 columns]
